# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset EDA

# %%
df_raw = pd.read_csv('dataset/male_players.csv')
len(df_raw)
# Out:
# 15845

# %%
df = df_raw.drop(['Unnamed: 0','URL', 'Gender','GK'],axis=1)
df.head()
# Out:
#               Name     Nation             Club Position  Age  Overall  Pace  \
# 0    Kylian Mbappé     France         Paris SG       ST   24       91    97
# 1   Erling Haaland     Norway  Manchester City       ST   23       91    89
# 2  Kevin De Bruyne    Belgium  Manchester City       CM   32       91    72
# 3     Lionel Messi  Argentina   Inter Miami CF       CF   36       90    80
# 4    Karim Benzema     France       Al Ittihad       CF   35       90    79
#
#    Shooting  Passing  Dribbling  ...  Sliding  Jumping  Stamina  Strength  \
# 0        90       80         93  ...       32       88       88        77
# 1        93       66         79  ...       29       93       76        93
# 2        88       94         86  ...       53       72       88        74
# 3        87       90         96  ...       24       71       70        68
# 4        88       83         87  ...       18       85       82        82
#
#    Aggression  Att work rate  Def work rate  Preferred foot  Weak foot  \
# 0          64           High            Low           Right          4
# 1          87           High         Medium            Left          3
# 2          75           High         Medium           Right          5
# 3          44            Low            Low            Left          4
# 4          63         Medium         Medium           Right          4
#
#    Skill moves
# 0            5
# 1            3
# 2            4
# 3            4
# 4            4
#
# [5 rows x 43 columns]

# %%
# Atur opsi tampilan angka desimal
pd.set_option('display.float_format', '{:.2f}'.format)
# Gunakan describe()
df.describe()
# Out:
#            Age  Overall     Pace  Shooting  Passing  Dribbling  Defending  \
# count 15845.00 15845.00 15845.00  15845.00 15845.00   15845.00   15845.00
# mean     25.85    66.32    68.13     54.14    58.53      56.30      50.87
# std       4.68     6.69    10.72     13.72     9.60      18.83      16.28
# min      17.00    47.00    27.00     19.00    25.00       5.00      15.00
# 25%      22.00    62.00    62.00     44.00    52.00      51.00      36.00
# 50%      25.00    66.00    69.00     57.00    59.00      62.00      55.00
# 75%      29.00    70.00    75.00     64.00    65.00      68.00      64.00
# max      43.00    91.00    97.00     93.00    94.00      96.00      89.00
#
#        Physicality  Acceleration   Sprint  ...  Heading      Def  Standing  \
# count     15845.00      15845.00 15845.00  ... 15845.00 15845.00  15845.00
# mean         65.46         64.72    64.89  ...    52.11    47.36     49.07
# std           9.57         15.46    15.26  ...    17.41    20.36     21.07
# min          29.00         14.00    15.00  ...     5.00     4.00      8.00
# 25%          59.00         57.00    57.00  ...    45.00    30.00     30.00
# 50%          66.00         68.00    68.00  ...    55.00    54.00     57.00
# 75%          72.00         75.00    75.00  ...    64.00    64.00     66.00
# max          90.00         97.00    97.00  ...    93.00    91.00     91.00
#
#        Sliding  Jumping  Stamina  Strength  Aggression  Weak foot  Skill moves
# count 15845.00 15845.00 15845.00  15845.00    15845.00   15845.00     15845.00
# mean     46.77    66.41    63.65     65.55       56.51       2.95         2.40
# std      20.62    11.66    16.45     12.55       16.86       0.68         0.78
# min       7.00    27.00    15.00     22.00       11.00       1.00         1.00
# 25%      27.00    59.00    57.00     58.00       46.00       3.00         2.00
# 50%      54.00    68.00    67.00     67.00       60.00       3.00         2.00
# 75%      64.00    75.00    75.00     74.00       69.00       3.00         3.00
# max      90.00    95.00    95.00     96.00       95.00       5.00         5.00
#
# [8 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15845 entries, 0 to 15844
# Data columns (total 43 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            15845 non-null  object
#  1   Nation          15845 non-null  object
#  2   Club            15845 non-null  object
#  3   Position        15845 non-null  object
#  4   Age             15845 non-null  int64
#  5   Overall         15845 non-null  int64
#  6   Pace            15845 non-null  int64
#  7   Shooting        15845 non-null  int64
#  8   Passing         15845 non-null  int64
#  9   Dribbling       15845 non-null  int64
#  10  Defending       15845 non-null  int64
#  11  Physicality     15845 non-null  int64
#  12  Acceleration    15845 non-null  int64
#  13  Sprint          15845 non-null  int64
#  14  Positioning     15845 non-null  int64
#  15  Finishing       15845 non-null  int64
#  16  Shot            15845 non-null  int64
#  17  Long            15845 non-null  int64
#  18  Volleys         15845 non-null  int64
#  19  Penalties       15845 non-null  int64
#  20  Vision          15845 non-null  int64
#  21  Crossing        15845 non-null  int64
#  22  Free            15845 non-null  int64
#  23  Curve           15845 non-null  int64
#  24  Agility         15845 non-null  int64
#  25  Balance         15845 non-null  int64
#  26  Reactions       15845 non-null  int64
#  27  Ball            15845 non-null  int64
#  28  Composure       15845 non-null  int64
#  29  Interceptions   15845 non-null  int64
#  30  Heading         15845 non-null  int64
#  31  Def             15845 non-null  int64
#  32  Standing        15845 non-null  int64
#  33  Sliding         15845 non-null  int64
#  34  Jumping         15845 non-null  int64
#  35  Stamina         15845 non-null  int64
#  36  Strength        15845 non-null  int64
#  37  Aggression      15845 non-null  int64
#  38  Att work rate   15845 non-null  object
#  39  Def work rate   15845 non-null  object
#  40  Preferred foot  15845 non-null  object
#  41  Weak foot       15845 non-null  int64
#  42  Skill moves     15845 non-null  int64
# dtypes: int64(36), object(7)
# memory usage: 5.2+ MB

# %%
print(df['Position'].value_counts())
# Out:
# Position
# CB     2865
# ST     2087
# CM     1923
# GK     1787
# CDM    1320
# RB      998
# LB      976
# CAM     853
# LM      839
# RM      825
# RW      380
# LW      341
# RWB     281
# LWB     254
# CF      116
# Name: count, dtype: int64

# %%
df.hist(figsize=(12, 8), edgecolor='black', grid=False)
plt.tight_layout()
plt.show()

# %%
df[df['Club'] == 'Manchester City'].head()
# Out:
#                Name    Nation             Club Position  Age  Overall  Pace  \
# 1    Erling Haaland    Norway  Manchester City       ST   23       91    89
# 2   Kevin De Bruyne   Belgium  Manchester City       CM   32       91    72
# 9        Rúben Dias  Portugal  Manchester City       CB   26       89    62
# 11            Rodri     Spain  Manchester City      CDM   27       89    58
# 20   Bernardo Silva  Portugal  Manchester City       CM   29       88    69
#
#     Shooting  Passing  Dribbling  ...  Sliding  Jumping  Stamina  Strength  \
# 1         93       66         79  ...       29       93       76        93
# 2         88       94         86  ...       53       72       88        74
# 9         39       66         64  ...       87       84       78        90
# 11        73       80         79  ...       78       80       89        83
# 20        78       86         92  ...       60       66       93        54
#
#     Aggression  Att work rate  Def work rate  Preferred foot  Weak foot  \
# 1           87           High         Medium            Left          3
# 2           75           High         Medium           Right          5
# 9           93         Medium           High           Right          4
# 11          83         Medium           High           Right          4
# 20          78           High           High            Left          3
#
#     Skill moves
# 1             3
# 2             4
# 9             2
# 11            3
# 20            4
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Jika tidak ada player yang mengisi posisi pada formasi?
# pisahkan data menjadi 3 bagian lapangan. Depan, Tengah, Belakang <br>
# Pemain depan: ['ST', 'CF', 'RW', 'LW']<br>
# Pemain tengah: ['CM', 'CDM', 'CAM', 'RM', 'LB', 'RB', 'LM']<br>
# Pemain belakang: ['GK', 'CB', 'LWB', 'RWB']

# %%
# Pisahkan pemain berdasarkan posisi
forwards = df[df['Position'].isin(['ST', 'CF', 'RW', 'LW'])]
midfielders = df[df['Position'].isin(['CM', 'CDM', 'CAM', 'RM', 'LM'])]
defenders = df[df['Position'].isin(['GK', 'CB', 'LB', 'RB', 'LWB', 'RWB'])]

# %%
defenders
# Out:
#                         Name    Nation              Club Position  Age  \
# 5           Thibaut Courtois   Belgium       Real Madrid       GK   31
# 9                 Rúben Dias  Portugal   Manchester City       CB   26
# 13     Marc-André ter Stegen   Germany      FC Barcelona       GK   31
# 14           Virgil van Dijk   Holland         Liverpool       CB   32
# 15                   Alisson    Brazil         Liverpool       GK   31
# ...                      ...       ...               ...      ...  ...
# 15834          Zhou Zhengkai  China PR  Shanghai Shenhua       GK   22
# 15836          Jin Liangkuan  China PR     Meizhou Hakka       CB   21
# 15837           Lyu Jiaqiang  China PR       Shenzhen FC       CB   18
# 15840          Deven Sawhney     India         Odisha FC       LB   21
# 15843              Ye Daoxin  China PR      Zhejiang Pro       CB   17
#
#        Overall  Pace  Shooting  Passing  Dribbling  ...  Sliding  Jumping  \
# 5           90    85        89       76         13  ...       16       68
# 9           89    62        39       66         64  ...       87       84
# 13          89    86        85       89         21  ...       10       72
# 14          89    78        60       71         70  ...       86       89
# 15          89    86        85       85         27  ...       16       82
# ...        ...   ...       ...      ...        ...  ...      ...      ...
# 15834       48    56        49       49         13  ...       13       41
# 15836       47    55        28       31         26  ...       48       36
# 15837       47    56        26       28         25  ...       53       40
# 15840       47    62        26       34         41  ...       47       45
# 15843       47    58        28       33         38  ...       46       38
#
#        Stamina  Strength  Aggression  Att work rate  Def work rate  \
# 5           38        70          23         Medium         Medium
# 9           78        90          93         Medium           High
# 13          35        78          43         Medium         Medium
# 14          72        93          85         Medium           High
# 15          32        78          27         Medium         Medium
# ...        ...       ...         ...            ...            ...
# 15834       24        50          22         Medium         Medium
# 15836       56        44          46         Medium         Medium
# 15837       39        52          43         Medium         Medium
# 15840       57        57          58           High         Medium
# 15843       50        48          46         Medium         Medium
#
#        Preferred foot  Weak foot  Skill moves
# 5                Left          3            1
# 9               Right          4            2
# 13              Right          4            1
# 14              Right          3            2
# 15              Right          3            1
# ...               ...        ...          ...
# 15834           Right          3            1
# 15836           Right          3            2
# 15837           Right          3            2
# 15840            Left          3            2
# 15843           Right          3            2
#
# [7161 rows x 43 columns]
