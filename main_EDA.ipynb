# %%
pip install pandas matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting numpy<2,>=1.23.2 (from pandas)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 651.3 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\project\python-pro\fc24_dream_team_ga\.venv\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.49.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ---------- ----------------------------- 41.0/162.3 kB ? eta -:--:--
#      ----------------------------------- -- 153.6/162.3 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------- 162.3/162.3 kB 1.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in e:\project\python-pro\fc24_dream_team_ga\.venv\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six>=1.5 in e:\project\python-pro\fc24_dream_team_ga\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 640.0 kB/s eta 0:00:19
#     --------------------------------------- 0.2/11.6 MB 2.1 MB/s eta 0:00:06
#     --------------------------------------- 0.2/11.6 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/11.6 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/11.6 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/11.6 MB 2.1 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/11.6 MB 2.1 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/11.6 MB 2.1 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/11.6 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.9/11.6 MB 2.1 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.6 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.1/11.6 MB 2.0 MB/s eta 0:00:06
#    --- ------------------------------------ 1.2/11.6 MB 2.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.6 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.4/11.6 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/11.6 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.6 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.7/11.6 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.6 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.9/11.6 MB 2.2 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.6 MB 2.2 MB/s eta 0:00:05
#    ------- -------------------------------- 2.2/11.6 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.3/11.6 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.3/11.6 MB 2.2 MB/s eta 0:00:05
#    ------- -------------------------------- 2.3/11.6 MB 2.2 MB/s eta 0:00:05
#    -------- ------------------------------- 2.3/11.6 MB 2.1 MB/s eta 0:00:05
#    -------- ------------------------------- 2.3/11.6 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.6 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.6 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/11.6 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.7/11.6 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.8/11.6 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/11.6 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.0/11.6 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/11.6 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.2/11.6 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.3/11.6 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/11.6 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.5/11.6 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.6/11.6 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.7/11.6 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.8/11.6 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 4.0/11.6 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.1/11.6 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.6 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.3/11.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.4/11.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.4/11.6 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.6/11.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.6/11.6 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.8/11.6 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.9/11.6 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.0/11.6 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.1/11.6 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.2/11.6 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.3/11.6 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.4/11.6 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.6 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.6/11.6 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.7/11.6 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.6 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.9/11.6 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 6.1/11.6 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.2/11.6 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.3/11.6 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.4/11.6 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.5/11.6 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.6/11.6 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.7/11.6 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.8/11.6 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.9/11.6 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 7.0/11.6 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 7.2/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.4/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.5/11.6 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.6 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.7/11.6 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.8/11.6 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 8.0/11.6 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 8.1/11.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.2/11.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.2/11.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.3/11.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.4/11.6 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.5/11.6 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.5/11.6 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.6/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.8/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.9/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 9.0/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 9.1/11.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 9.3/11.6 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 9.5/11.6 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.6 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.8/11.6 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.9/11.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.1/11.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.4/11.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.6/11.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.7/11.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.9/11.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.2/11.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 2.3 MB/s eta 0:00:00
# Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.6 MB 2.0 MB/s eta 0:00:04
#    ---------------------------------------- 0.1/7.6 MB 2.6 MB/s eta 0:00:03
#     --------------------------------------- 0.1/7.6 MB 1.3 MB/s eta 0:00:06
#    - -------------------------------------- 0.2/7.6 MB 1.4 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/7.6 MB 1.5 MB/s eta 0:00:05
#    -- ------------------------------------- 0.4/7.6 MB 1.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/7.6 MB 1.8 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/7.6 MB 1.9 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/7.6 MB 1.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/7.6 MB 2.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.9/7.6 MB 2.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.6 MB 2.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.1/7.6 MB 2.0 MB/s eta 0:00:04
#    ------ --------------------------------- 1.2/7.6 MB 2.0 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/7.6 MB 2.1 MB/s eta 0:00:04
#    ------- -------------------------------- 1.4/7.6 MB 2.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/7.6 MB 2.1 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.6 MB 2.1 MB/s eta 0:00:03
#    -------- ------------------------------- 1.7/7.6 MB 2.2 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/7.6 MB 2.2 MB/s eta 0:00:03
#    --------- ------------------------------ 1.9/7.6 MB 2.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.0/7.6 MB 2.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/7.6 MB 2.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.2/7.6 MB 2.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.3/7.6 MB 2.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.4/7.6 MB 2.3 MB/s eta 0:00:03
#    ------------- -------------------------- 2.5/7.6 MB 2.3 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/7.6 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.7/7.6 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.8/7.6 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 2.9/7.6 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 3.0/7.6 MB 2.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.6 MB 2.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.2/7.6 MB 2.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.3/7.6 MB 2.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/7.6 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.5/7.6 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.6/7.6 MB 2.3 MB/s eta 0:00:02
#    ------------------- -------------------- 3.7/7.6 MB 2.3 MB/s eta 0:00:02
#    -------------------- ------------------- 3.9/7.6 MB 2.3 MB/s eta 0:00:02
#    -------------------- ------------------- 4.0/7.6 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 4.1/7.6 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 4.2/7.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.3/7.6 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.4/7.6 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.6 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 4.7/7.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 4.8/7.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 4.9/7.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.0/7.6 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 5.1/7.6 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/7.6 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 5.2/7.6 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.4/7.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.6 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.6 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.6 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.8/7.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.0/7.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 6.2/7.6 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.6 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.4/7.6 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.5/7.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.8/7.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.9/7.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.0/7.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.2/7.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.2/7.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.3/7.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.4/7.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 2.3 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.6 kB ? eta -:--:--
#    ------------------- -------------------- 92.2/187.6 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 187.6/187.6 kB 2.3 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.49.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.2 MB 2.2 MB/s eta 0:00:01
#    --- ------------------------------------ 0.2/2.2 MB 2.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.2 MB 2.6 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.2 MB 2.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.2 MB 2.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.2 MB 2.7 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 2.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.2 MB 2.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 2.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 2.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 2.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 2.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 2.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.2 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.2 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 2.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 1.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.8 MB 3.3 MB/s eta 0:00:05
#     --------------------------------------- 0.2/15.8 MB 2.6 MB/s eta 0:00:06
#     --------------------------------------- 0.3/15.8 MB 2.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/15.8 MB 2.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/15.8 MB 2.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/15.8 MB 2.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/15.8 MB 2.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/15.8 MB 2.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/15.8 MB 2.3 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/15.8 MB 2.3 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/15.8 MB 2.2 MB/s eta 0:00:07
#    -- ------------------------------------- 1.1/15.8 MB 2.3 MB/s eta 0:00:07
#    --- ------------------------------------ 1.2/15.8 MB 2.3 MB/s eta 0:00:07
#    --- ------------------------------------ 1.4/15.8 MB 2.4 MB/s eta 0:00:07
#    --- ------------------------------------ 1.5/15.8 MB 2.4 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/15.8 MB 2.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/15.8 MB 2.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.7/15.8 MB 2.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.8/15.8 MB 2.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.9/15.8 MB 2.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.0/15.8 MB 2.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.2/15.8 MB 2.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.3/15.8 MB 2.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.4/15.8 MB 2.4 MB/s eta 0:00:06
#    ------ --------------------------------- 2.5/15.8 MB 2.4 MB/s eta 0:00:06
#    ------ --------------------------------- 2.6/15.8 MB 2.4 MB/s eta 0:00:06
#    ------ --------------------------------- 2.7/15.8 MB 2.4 MB/s eta 0:00:06
#    ------- -------------------------------- 2.8/15.8 MB 2.4 MB/s eta 0:00:06
#    ------- -------------------------------- 2.9/15.8 MB 2.4 MB/s eta 0:00:06
#    ------- -------------------------------- 3.0/15.8 MB 2.4 MB/s eta 0:00:06
#    ------- -------------------------------- 3.1/15.8 MB 2.4 MB/s eta 0:00:06
#    -------- ------------------------------- 3.2/15.8 MB 2.5 MB/s eta 0:00:06
#    -------- ------------------------------- 3.4/15.8 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 3.5/15.8 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.6/15.8 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.7/15.8 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.8/15.8 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.9/15.8 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.0/15.8 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.1/15.8 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/15.8 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.3/15.8 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.3/15.8 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.4/15.8 MB 2.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.5/15.8 MB 2.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.6/15.8 MB 2.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.7/15.8 MB 2.4 MB/s eta 0:00:05
#    ------------ --------------------------- 4.8/15.8 MB 2.4 MB/s eta 0:00:05
#    ------------ --------------------------- 4.8/15.8 MB 2.4 MB/s eta 0:00:05
#    ------------ --------------------------- 4.8/15.8 MB 2.4 MB/s eta 0:00:05
#    ------------ --------------------------- 4.9/15.8 MB 2.3 MB/s eta 0:00:05
#    ------------ --------------------------- 4.9/15.8 MB 2.3 MB/s eta 0:00:05
#    ------------ --------------------------- 4.9/15.8 MB 2.3 MB/s eta 0:00:05
#    ------------ --------------------------- 4.9/15.8 MB 2.3 MB/s eta 0:00:05
#    ------------ --------------------------- 4.9/15.8 MB 2.2 MB/s eta 0:00:05
#    ------------ --------------------------- 5.0/15.8 MB 2.2 MB/s eta 0:00:06
#    ------------ --------------------------- 5.1/15.8 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.2/15.8 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.4/15.8 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.4/15.8 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.5/15.8 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.5/15.8 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.5/15.8 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.6/15.8 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.6/15.8 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.6/15.8 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.6/15.8 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.6/15.8 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.6/15.8 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.7/15.8 MB 1.9 MB/s eta 0:00:06
#    -------------- ------------------------- 5.7/15.8 MB 1.9 MB/s eta 0:00:06
#    -------------- ------------------------- 5.7/15.8 MB 1.9 MB/s eta 0:00:06
#    -------------- ------------------------- 5.7/15.8 MB 1.9 MB/s eta 0:00:06
#    -------------- ------------------------- 5.8/15.8 MB 1.9 MB/s eta 0:00:06
#    -------------- ------------------------- 5.9/15.8 MB 1.8 MB/s eta 0:00:06
#    --------------- ------------------------ 5.9/15.8 MB 1.9 MB/s eta 0:00:06
#    --------------- ------------------------ 6.0/15.8 MB 1.8 MB/s eta 0:00:06
#    --------------- ------------------------ 6.0/15.8 MB 1.8 MB/s eta 0:00:06
#    --------------- ------------------------ 6.1/15.8 MB 1.8 MB/s eta 0:00:06
#    --------------- ------------------------ 6.2/15.8 MB 1.8 MB/s eta 0:00:06
#    --------------- ------------------------ 6.2/15.8 MB 1.8 MB/s eta 0:00:06
#    --------------- ------------------------ 6.3/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.3/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.4/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.5/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.6/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.7/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.7/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.7/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.8/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.8/15.8 MB 1.6 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.9/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 7.0/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 7.0/15.8 MB 1.6 MB/s eta 0:00:06
#    ----------------- ---------------------- 7.1/15.8 MB 1.6 MB/s eta 0:00:06
#    ------------------ --------------------- 7.1/15.8 MB 1.6 MB/s eta 0:00:06
#    ------------------ --------------------- 7.2/15.8 MB 1.6 MB/s eta 0:00:06
#    ------------------ --------------------- 7.3/15.8 MB 1.6 MB/s eta 0:00:06
#    ------------------ --------------------- 7.4/15.8 MB 1.6 MB/s eta 0:00:06
#    ------------------ --------------------- 7.4/15.8 MB 1.6 MB/s eta 0:00:06
#    ------------------- -------------------- 7.6/15.8 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 7.6/15.8 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 7.7/15.8 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 7.8/15.8 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 7.9/15.8 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 8.0/15.8 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 8.1/15.8 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 8.2/15.8 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 8.2/15.8 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 8.3/15.8 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 8.6/15.8 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 8.7/15.8 MB 1.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 8.8/15.8 MB 1.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 8.9/15.8 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.0/15.8 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.1/15.8 MB 1.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.2/15.8 MB 1.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.3/15.8 MB 1.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.5/15.8 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.6/15.8 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.7/15.8 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.8/15.8 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 9.9/15.8 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 10.0/15.8 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 10.1/15.8 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 10.3/15.8 MB 1.8 MB/s eta 0:00:04
#    -------------------------- ------------- 10.3/15.8 MB 1.8 MB/s eta 0:00:04
#    -------------------------- ------------- 10.4/15.8 MB 1.8 MB/s eta 0:00:03
#    -------------------------- ------------- 10.6/15.8 MB 1.8 MB/s eta 0:00:03
#    -------------------------- ------------- 10.6/15.8 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 10.7/15.8 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 10.8/15.8 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 10.9/15.8 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 11.0/15.8 MB 1.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.1/15.8 MB 1.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.2/15.8 MB 1.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.3/15.8 MB 1.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.4/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.5/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.6/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.6/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.7/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.7/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.8/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.8/15.8 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.8/15.8 MB 1.8 MB/s eta 0:00:03
#    ------------------------------ --------- 11.9/15.8 MB 1.8 MB/s eta 0:00:03
#    ------------------------------ --------- 11.9/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 11.9/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.0/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.0/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.0/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 12.2/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.4/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.4/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.5/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.5/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.5/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.6/15.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.6/15.8 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.7/15.8 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.8 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.8 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.9/15.8 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 13.0/15.8 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 13.0/15.8 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.8 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 13.2/15.8 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 13.2/15.8 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 13.3/15.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 13.3/15.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 13.4/15.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.5/15.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.6/15.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.6/15.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.7/15.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.8/15.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.8/15.8 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.9/15.8 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.0/15.8 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.1/15.8 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.1/15.8 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.2/15.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------ --- 14.3/15.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------ --- 14.3/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.5/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.5/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.5/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/15.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.4/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 1.4 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/2.6 MB 1.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.1/2.6 MB 1.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/2.6 MB 1.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.6 MB 1.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.6 MB 1.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.6 MB 1.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.4/2.6 MB 1.3 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.6 MB 1.3 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/2.6 MB 1.3 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/2.6 MB 1.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.7/2.6 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.6 MB 1.6 MB/s eta 0:00:02
#    ------------- -------------------------- 0.9/2.6 MB 1.7 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.6 MB 1.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 1.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.6 MB 1.9 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.6 MB 1.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.6 MB 1.8 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 1.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.2/2.6 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 1.6 MB/s eta 0:00:00
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    -------- ------------------------------- 112.6/505.5 kB 3.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 225.3/505.5 kB 2.8 MB/s eta 0:00:01
#    ------------------------- -------------- 317.4/505.5 kB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 399.4/505.5 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  501.8/505.5 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 2.3 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    ------------- -------------------------- 112.6/345.4 kB 3.2 MB/s eta 0:00:01
#    -------------------------- ------------- 225.3/345.4 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  337.9/345.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 numpy-1.26.4 pandas-2.2.1 pillow-10.2.0 pyparsing-3.1.1 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_raw = pd.read_csv('dataset/male_players.csv')
df_raw
# Out:
#        Unnamed: 0             Name     Nation             Club Position  Age  \
# 0               0    Kylian Mbappé     France         Paris SG       ST   24
# 1               1   Erling Haaland     Norway  Manchester City       ST   23
# 2               2  Kevin De Bruyne    Belgium  Manchester City       CM   32
# 3               3     Lionel Messi  Argentina   Inter Miami CF       CF   36
# 4               4    Karim Benzema     France       Al Ittihad       CF   35
# ...           ...              ...        ...              ...      ...  ...
# 15840       15840    Deven Sawhney      India        Odisha FC       LB   21
# 15841       15841      Wang Tengda   China PR       Dalian Pro       CM   22
# 15842       15842        Wu Yuhang   China PR     Zhejiang Pro      CDM   22
# 15843       15843        Ye Daoxin   China PR     Zhejiang Pro       CB   17
# 15844       15844          Yin Jie   China PR     Zhejiang Pro       CM   22
#
#        Overall  Pace  Shooting  Passing  ...  Strength  Aggression  \
# 0           91    97        90       80  ...        77          64
# 1           91    89        93       66  ...        93          87
# 2           91    72        88       94  ...        74          75
# 3           90    80        87       90  ...        68          44
# 4           90    79        88       83  ...        82          63
# ...        ...   ...       ...      ...  ...       ...         ...
# 15840       47    62        26       34  ...        57          58
# 15841       47    61        37       45  ...        42          51
# 15842       47    56        34       43  ...        51          56
# 15843       47    58        28       33  ...        48          46
# 15844       47    57        37       46  ...        60          50
#
#        Att work rate  Def work rate  Preferred foot  Weak foot  Skill moves  \
# 0               High            Low           Right          4            5
# 1               High         Medium            Left          3            3
# 2               High         Medium           Right          5            4
# 3                Low            Low            Left          4            4
# 4             Medium         Medium           Right          4            4
# ...              ...            ...             ...        ...          ...
# 15840           High         Medium            Left          3            2
# 15841         Medium         Medium           Right          3            2
# 15842         Medium         Medium           Right          3            2
# 15843         Medium         Medium           Right          3            2
# 15844         Medium         Medium           Right          3            2
#
#                                                      URL  Gender  GK
# 0      https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 1      https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 2      https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 3      https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 4      https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# ...                                                  ...     ...  ..
# 15840  https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 15841  https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 15842  https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 15843  https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
# 15844  https://www.ea.com/games/ea-sports-fc/ratings/...       M NaN
#
# [15845 rows x 47 columns]

# %%
df = df_raw.drop(['Unnamed: 0','URL', 'Gender','GK'],axis=1)
df
# Out:
#                   Name     Nation             Club Position  Age  Overall  \
# 0        Kylian Mbappé     France         Paris SG       ST   24       91
# 1       Erling Haaland     Norway  Manchester City       ST   23       91
# 2      Kevin De Bruyne    Belgium  Manchester City       CM   32       91
# 3         Lionel Messi  Argentina   Inter Miami CF       CF   36       90
# 4        Karim Benzema     France       Al Ittihad       CF   35       90
# ...                ...        ...              ...      ...  ...      ...
# 15840    Deven Sawhney      India        Odisha FC       LB   21       47
# 15841      Wang Tengda   China PR       Dalian Pro       CM   22       47
# 15842        Wu Yuhang   China PR     Zhejiang Pro      CDM   22       47
# 15843        Ye Daoxin   China PR     Zhejiang Pro       CB   17       47
# 15844          Yin Jie   China PR     Zhejiang Pro       CM   22       47
#
#        Pace  Shooting  Passing  Dribbling  ...  Sliding  Jumping  Stamina  \
# 0        97        90       80         93  ...       32       88       88
# 1        89        93       66         79  ...       29       93       76
# 2        72        88       94         86  ...       53       72       88
# 3        80        87       90         96  ...       24       71       70
# 4        79        88       83         87  ...       18       85       82
# ...     ...       ...      ...        ...  ...      ...      ...      ...
# 15840    62        26       34         41  ...       47       45       57
# 15841    61        37       45         45  ...       44       38       56
# 15842    56        34       43         43  ...       51       38       49
# 15843    58        28       33         38  ...       46       38       50
# 15844    57        37       46         43  ...       45       48       59
#
#        Strength  Aggression  Att work rate  Def work rate  Preferred foot  \
# 0            77          64           High            Low           Right
# 1            93          87           High         Medium            Left
# 2            74          75           High         Medium           Right
# 3            68          44            Low            Low            Left
# 4            82          63         Medium         Medium           Right
# ...         ...         ...            ...            ...             ...
# 15840        57          58           High         Medium            Left
# 15841        42          51         Medium         Medium           Right
# 15842        51          56         Medium         Medium           Right
# 15843        48          46         Medium         Medium           Right
# 15844        60          50         Medium         Medium           Right
#
#        Weak foot  Skill moves
# 0              4            5
# 1              3            3
# 2              5            4
# 3              4            4
# 4              4            4
# ...          ...          ...
# 15840          3            2
# 15841          3            2
# 15842          3            2
# 15843          3            2
# 15844          3            2
#
# [15845 rows x 43 columns]

# %%
# Atur opsi tampilan angka desimal
pd.set_option('display.float_format', '{:.2f}'.format)
# Gunakan describe()
df.describe()
# Out:
#            Age  Overall     Pace  Shooting  Passing  Dribbling  Defending  \
# count 15845.00 15845.00 15845.00  15845.00 15845.00   15845.00   15845.00
# mean     25.85    66.32    68.13     54.14    58.53      56.30      50.87
# std       4.68     6.69    10.72     13.72     9.60      18.83      16.28
# min      17.00    47.00    27.00     19.00    25.00       5.00      15.00
# 25%      22.00    62.00    62.00     44.00    52.00      51.00      36.00
# 50%      25.00    66.00    69.00     57.00    59.00      62.00      55.00
# 75%      29.00    70.00    75.00     64.00    65.00      68.00      64.00
# max      43.00    91.00    97.00     93.00    94.00      96.00      89.00
#
#        Physicality  Acceleration   Sprint  ...  Heading      Def  Standing  \
# count     15845.00      15845.00 15845.00  ... 15845.00 15845.00  15845.00
# mean         65.46         64.72    64.89  ...    52.11    47.36     49.07
# std           9.57         15.46    15.26  ...    17.41    20.36     21.07
# min          29.00         14.00    15.00  ...     5.00     4.00      8.00
# 25%          59.00         57.00    57.00  ...    45.00    30.00     30.00
# 50%          66.00         68.00    68.00  ...    55.00    54.00     57.00
# 75%          72.00         75.00    75.00  ...    64.00    64.00     66.00
# max          90.00         97.00    97.00  ...    93.00    91.00     91.00
#
#        Sliding  Jumping  Stamina  Strength  Aggression  Weak foot  Skill moves
# count 15845.00 15845.00 15845.00  15845.00    15845.00   15845.00     15845.00
# mean     46.77    66.41    63.65     65.55       56.51       2.95         2.40
# std      20.62    11.66    16.45     12.55       16.86       0.68         0.78
# min       7.00    27.00    15.00     22.00       11.00       1.00         1.00
# 25%      27.00    59.00    57.00     58.00       46.00       3.00         2.00
# 50%      54.00    68.00    67.00     67.00       60.00       3.00         2.00
# 75%      64.00    75.00    75.00     74.00       69.00       3.00         3.00
# max      90.00    95.00    95.00     96.00       95.00       5.00         5.00
#
# [8 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15845 entries, 0 to 15844
# Data columns (total 43 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            15845 non-null  object
#  1   Nation          15845 non-null  object
#  2   Club            15845 non-null  object
#  3   Position        15845 non-null  object
#  4   Age             15845 non-null  int64
#  5   Overall         15845 non-null  int64
#  6   Pace            15845 non-null  int64
#  7   Shooting        15845 non-null  int64
#  8   Passing         15845 non-null  int64
#  9   Dribbling       15845 non-null  int64
#  10  Defending       15845 non-null  int64
#  11  Physicality     15845 non-null  int64
#  12  Acceleration    15845 non-null  int64
#  13  Sprint          15845 non-null  int64
#  14  Positioning     15845 non-null  int64
#  15  Finishing       15845 non-null  int64
#  16  Shot            15845 non-null  int64
#  17  Long            15845 non-null  int64
#  18  Volleys         15845 non-null  int64
#  19  Penalties       15845 non-null  int64
#  20  Vision          15845 non-null  int64
#  21  Crossing        15845 non-null  int64
#  22  Free            15845 non-null  int64
#  23  Curve           15845 non-null  int64
#  24  Agility         15845 non-null  int64
#  25  Balance         15845 non-null  int64
#  26  Reactions       15845 non-null  int64
#  27  Ball            15845 non-null  int64
#  28  Composure       15845 non-null  int64
#  29  Interceptions   15845 non-null  int64
#  30  Heading         15845 non-null  int64
#  31  Def             15845 non-null  int64
#  32  Standing        15845 non-null  int64
#  33  Sliding         15845 non-null  int64
#  34  Jumping         15845 non-null  int64
#  35  Stamina         15845 non-null  int64
#  36  Strength        15845 non-null  int64
#  37  Aggression      15845 non-null  int64
#  38  Att work rate   15845 non-null  object
#  39  Def work rate   15845 non-null  object
#  40  Preferred foot  15845 non-null  object
#  41  Weak foot       15845 non-null  int64
#  42  Skill moves     15845 non-null  int64
# dtypes: int64(36), object(7)
# memory usage: 5.2+ MB

# %%
print(df['Position'].value_counts())
# Out:
# Position
# CB     2865
# ST     2087
# CM     1923
# GK     1787
# CDM    1320
# RB      998
# LB      976
# CAM     853
# LM      839
# RM      825
# RW      380
# LW      341
# RWB     281
# LWB     254
# CF      116
# Name: count, dtype: int64

# %%
df.hist(figsize=(12, 8), edgecolor='black', grid=False)
plt.tight_layout()
plt.show()

# %%
correlation = df['Esport_Wins'].corr(df['Phy_Damage'])
print(f"Korelasi antara Esport_Wins dan Primary_Role: {correlation}")
# Out:
# Korelasi antara Esport_Wins dan Primary_Role: -0.05819912546323813

# %%
df = df[['Name', 'Primary_Role', 'Lane', 'Hp', 'Phy_Damage', 'Mov_Speed', 'Hero_Defense', 'Esport_Wins', 'Esport_Loss']]

# %% [markdown]
# Hard Engage = AD + MV <br>
# Team Fight = AD + HP + PD

# %%
df['Win_Rate'] = df['Esport_Wins'] / (df['Esport_Wins'] + df['Esport_Loss'])
df['Hard_Engage'] = (df['Phy_Damage'] + df['Mov_Speed'])
df['Team_Fight'] = (df['Phy_Damage'] + df['Hp'] + df['Hero_Defense'])
# Out:
# C:\Users\ROSYID\AppData\Local\Temp\ipykernel_17780\1658631455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Win_Rate'] = df['Esport_Wins'] / (df['Esport_Wins'] + df['Esport_Loss'])
# C:\Users\ROSYID\AppData\Local\Temp\ipykernel_17780\1658631455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hard_Engage'] = (df['Phy_Damage'] + df['Mov_Speed'])
# C:\Users\ROSYID\AppData\Local\Temp\ipykernel_17780\1658631455.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Team_Fight'] = (df['Phy_Damage'] + df['Hp'] + df['Hero_Defense'])

# %%
exp = df[df['Lane'] == 'EXP Lane']
exp.head()
# Out:
#       Name Primary_Role      Lane    Hp  Phy_Damage  Mov_Speed  Hero_Defense
# 2   Aldous      Fighter  EXP Lane  2718         129        260            36  \
# 3    Alice         Mage  EXP Lane  2573         114        240            36
# 4    Alpha      Fighter  EXP Lane  2646         121        260            40
# 7    Argus      Fighter  EXP Lane  2628         100        260            36
# 10   Aulus      Fighter  EXP Lane  2758          90        255            39
#
#     Esport_Wins  Esport_Loss  Win_Rate  Hard_Engage  Team_Fight
# 2            95           92      0.51          389        2883
# 3           364          352      0.51          354        2723
# 4            24           33      0.42          381        2807
# 7             2            7      0.22          360        2764
# 10          114          109      0.51          345        2887

# %%
mid = df[df['Lane'] == 'Mid']
mid.head()
# Out:
#         Name Primary_Role Lane    Hp  Phy_Damage  Mov_Speed  Hero_Defense
# 9     Aurora         Mage  Mid  2501         110        245            32  \
# 22  Cecilion         Mage  Mid  2456         105        255            33
# 23   Chang'e         Mage  Mid  2301         115        240            31
# 27   Cyclops         Mage  Mid  2521         112        240            33
# 33    Eudora         Mage  Mid  2524         112        250            34
#
#     Esport_Wins  Esport_Loss  Win_Rate  Hard_Engage  Team_Fight
# 9            28           26      0.52          355        2643
# 22          470          588      0.44          360        2594
# 23          221          285      0.44          355        2447
# 27           69           90      0.43          352        2666
# 33           78           67      0.54          362        2670

# %%
gold = df[df['Lane'] == 'Gold Lane']
gold.head()
# Out:
#        Name Primary_Role       Lane    Hp  Phy_Damage  Mov_Speed
# 16  Beatrix     Marksman  Gold Lane  2550         102        257  \
# 19    Brody     Marksman  Gold Lane  2490         105        253
# 20    Bruno     Marksman  Gold Lane  2522         140        240
# 24     Chou      Fighter  Gold Lane  2708         121        260
# 25   Claude     Marksman  Gold Lane  2370          97        240
#
#     Hero_Defense  Esport_Wins  Esport_Loss  Win_Rate  Hard_Engage  Team_Fight
# 16            35         1016          969      0.51          359        2687
# 19            35          470          476      0.50          358        2630
# 20            32          154          154      0.50          380        2694
# 24            38         1139         1057      0.52          381        2867
# 25            29          618          583      0.51          337        2496

# %%
roamer = df[df['Lane'] == 'Roamer']
roamer.head()
# Out:
#         Name Primary_Role    Lane    Hp  Phy_Damage  Mov_Speed  Hero_Defense
# 1       Akai         Tank  Roamer  2769         115        260            39  \
# 6     Angela      Support  Roamer  2421         115        240            30
# 8      Atlas         Tank  Roamer  2819         135        240            36
# 17  Belerick         Tank  Roamer  2569         110        250            30
# 21  Carmilla      Support  Roamer  2528         126        255            40
#
#     Esport_Wins  Esport_Loss  Win_Rate  Hard_Engage  Team_Fight
# 1           540          524      0.51          375        2923
# 6           253          325      0.44          355        2566
# 8           277          254      0.52          375        2990
# 17           57           71      0.45          360        2709
# 21           32           47      0.41          381        2694

# %%
jungler = df[df['Lane'] == 'Jungler']
jungler.head()
# Out:
#        Name Primary_Role     Lane    Hp  Phy_Damage  Mov_Speed  Hero_Defense
# 0     Aamon     Assassin  Jungler  2614         115        250            34  \
# 5   Alucard      Fighter  Jungler  2621         123        260            36
# 13     Bane      Fighter  Jungler  2559         117        260            38
# 15    Baxia         Tank  Jungler  2769         125        240            38
# 34    Fanny     Assassin  Jungler  2526         126        265            34
#
#     Esport_Wins  Esport_Loss  Win_Rate  Hard_Engage  Team_Fight
# 0            43           42      0.51          365        2763
# 5            22           33      0.40          383        2780
# 13           95          111      0.46          377        2714
# 15          450          465      0.49          365        2932
# 34          189          196      0.49          391        2686

# %% [markdown]
# Hard Engage
# Attack Defense + Movement Speed

# %%
# EXP
he_exp_max = exp['Hard_Engage'].max()
hero_exp_max = exp[exp['Hard_Engage'] == he_exp_max]['Name'].iloc[0]
print('Nama:',hero_exp_max)
print('Skor:', he_exp_max)
# Out:
# Nama: Barats
# Skor: 403

# %%
he_mid_max = mid['Hard_Engage'].max()
hero_mid_max = mid[mid['Hard_Engage'] == he_mid_max]['Name'].iloc[0]
print('Nama:',hero_mid_max)
print('Skor:', he_mid_max)
# Out:
# Nama: Yve
# Skor: 370

# %%
he_gold_max = gold['Hard_Engage'].max()
hero_gold_max = gold[gold['Hard_Engage'] == he_gold_max]['Name'].iloc[0]
print('Nama:',hero_gold_max)
print('Skor:', he_gold_max)
# Out:
# Nama: Zilong
# Skor: 388

# %%
he_roamer_max = roamer['Hard_Engage'].max()
hero_roamer_max = roamer[roamer['Hard_Engage'] == he_roamer_max]['Name'].iloc[0]
print('Nama:',hero_roamer_max)
print('Skor:', he_roamer_max)
# Out:
# Nama: Grock
# Skor: 395

# %%
he_jungler_max = jungler['Hard_Engage'].max()
hero_jungler_max = jungler[jungler['Hard_Engage'] == he_jungler_max]['Name'].iloc[0]
print('Nama:',hero_jungler_max)
print('Skor:', he_jungler_max)
# Out:
# Nama: Fanny
# Skor: 391

# %%
max_fv = he_exp_max + he_mid_max + he_gold_max+he_roamer_max+he_jungler_max
max_fv
# Out:
# 1947

# %%
class LOLTeam:
    def __init__(self, heroes):
        self.heroes = heroes

    def calculate_fitness(self):
        # Calculate total attack damage
        total_attack_damage = sum(hero['attack_damage'] for hero in self.heroes)

        # Calculate total movement speed
        total_movement_speed = sum(hero['movement_speed'] for hero in self.heroes)

        # Define roles and count occurrences
        roles = [hero['role'] for hero in self.heroes]
        role_counts = {role: roles.count(role) for role in set(roles)}

        # Assign fitness based on balanced roles and high attack damage
        role_fitness = sum((count - 1) ** 2 for count in role_counts.values())  # Penalize imbalance
        attack_damage_fitness = total_attack_damage
        movement_speed_fitness = total_movement_speed

        # Combine the three fitness components
        total_fitness = role_fitness + attack_damage_fitness + movement_speed_fitness

        return total_fitness

# Example heroes (replace with actual hero data)
hero1 = {'role': 'Tank', 'attack_damage': 80, 'movement_speed': 330}
hero2 = {'role': 'ADC', 'attack_damage': 100, 'movement_speed': 325}
hero3 = {'role': 'Mage', 'attack_damage': 90, 'movement_speed': 340}
hero4 = {'role': 'Support', 'attack_damage': 50, 'movement_speed': 335}
hero5 = {'role': 'Tank', 'attack_damage': 70, 'movement_speed': 325}

# Create a LOLTeam instance
team = LOLTeam([hero1, hero2, hero3, hero4, hero5])

# Calculate the fitness of the team
fitness = team.calculate_fitness()

print(f"The fitness of the team is: {fitness}")
# Out:
# The fitness of the team is: 2046

# %% [markdown]
# Test rosyid

# %%
df.shape
# Out:
# (114, 12)

# %%
import numpy as np

# %%
df.columns
# Out:
# Index(['Name', 'Primary_Role', 'Lane', 'Hp', 'Phy_Damage', 'Mov_Speed',
#        'Hero_Defense', 'Esport_Wins', 'Esport_Loss', 'Win_Rate', 'Hard_Engage',
#        'Team_Fight'],
#       dtype='object')

# %%
df = pd.concat([
    df[df['Primary_Role'] == 'Marksman'], 
    df[df['Primary_Role'] == 'Mage'], 
    df[df['Primary_Role'] == 'Fighter'], 
    df[df['Primary_Role'] == 'Tank'], 
    df[df['Primary_Role'] == 'Support'], 
    df[df['Primary_Role'] == 'Assassin']
    ], axis=0).reset_index(drop=True)
df.index += 1

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\MKOM\SMT2\KKPM\MLBB_GenethicAlgorithm\main.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/MKOM/SMT2/KKPM/MLBB_GenethicAlgorithm/main.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> df
#
# NameError: name 'df' is not defined

# %%
df.loc[20]
# Out:
# Name            Aurora
# Primary_Role      Mage
# Lane               Mid
# Hp                2501
# Phy_Damage         110
# Mov_Speed          245
# Hero_Defense        32
# Esport_Wins         28
# Esport_Loss         26
# Win_Rate          0.52
# Hard_Engage        355
# Team_Fight        2643
# Name: 20, dtype: object

# %%
#add total pick
df['Win_Rate']
# Out:
# 1     0.51
# 2     0.50
# 3     0.50
# 4     0.51
# 5     0.50
#       ...
# 110   0.51
# 111   0.51
# 112   0.50
# 113   0.48
# 114   0.54
# Name: Win_Rate, Length: 114, dtype: float64

# %%
import random

def generate_individual(chromosome_length):
    def random_integer_except(excluded_value):
        while True:
            random_value = random.randint(44, 94)  # Ganti rentang sesuai kebutuhan Anda
            if random_value != excluded_value:
                return random_value
    # Fungsi ini menghasilkan satu individu acak dengan panjang kromosom tertentu.
    individual= [0]*5
    individual[0] = random.randint(1,18)
    individual[1] = random.randint(19,43)
    individual[2] = random.randint(44,76)
    individual[3] = random.randint(77,101)
    individual[4] = random.choice([random_integer_except([individual[2],individual[3]]), random.randint(102,114)])

    return individual

def initialize_population(population_size, chromosome_length):
    # Fungsi ini menghasilkan populasi awal dengan sejumlah individu.
    return [generate_individual(chromosome_length) for _ in range(population_size)]

# Contoh penggunaan
population_size = 20
chromosome_length = 5

population = initialize_population(population_size, chromosome_length)
print("Populasi Awal:")
for individual in population:
    hero1=df['Name'][individual[0]]
    hero2=df['Name'][individual[1]]
    hero3=df['Name'][individual[2]]
    hero4=df['Name'][individual[3]]
    hero5=df['Name'][individual[4]]
    tim=[hero1, hero2, hero3, hero4, hero5]
    print(tim)
# Out:
# Populasi Awal:
# ['Irithel', 'Gord', 'Terizla', 'Johnson', 'Hayabusa']
# ['Beatrix', 'Lylia', 'Julian', 'Uranus', 'Yi_Sun-Shin']
# ['Kimmy', 'Eudora', 'Yu_Zhong', 'Fredrinn', 'Ling']
# ['Claude', 'Alice', 'Thamuz', 'Khufra', 'Aamon']
# ['Lesley', 'Nana', 'Zilong', 'Diggie', 'Minsitthar']
# ['Kimmy', 'Gord', 'Zilong', 'Uranus', 'Aamon']
# ['Irithel', 'Luo_Yi', 'Yin', 'Akai', 'Minsitthar']
# ['Karrie', 'Gord', 'Paquito', 'Johnson', 'Edith']
# ['Natan', 'Vale', 'Masha', 'Grock', 'Julian']
# ['Kimmy', 'Pharsa', 'Terizla', 'Gatotkaca', 'Aldous']
# ['Popol_and_Kupa', 'Valir', 'Argus', 'Gatotkaca', 'Martis']
# ['Clint', 'Zhask', 'Alucard', 'Floryn', 'Fanny']
# ['Kimmy', 'Eudora', 'Yin', 'Rafaela', 'Minsitthar']
# ['Brody', 'Kagura', 'X.Borg', 'Gloo', 'Karina']
# ['Beatrix', 'Cyclops', 'Guinevere', 'Faramis', 'Selena']
# ['Moskov', 'Valentina', 'Argus', 'Barats', 'Johnson']
# ['Irithel', 'Vexana', 'Masha', 'Grock', 'Aamon']
# ['Natan', 'Harith', 'Bane', 'Franco', 'Selena']
# ['Karrie', 'Lunox', 'Dyrroth', 'Faramis', 'Chou']
# ['Moskov', 'Eudora', 'Jawhead', 'Gatotkaca', 'Masha']

# %%
#fitness
def fitness_starg1(team):
    ind1=0
    ind2=0
    for h in team:
        ind1 += df['Hard_Engage'][h]
        ind2 += df['Win_Rate'][h]
    fit = ind1 * (ind2/5)
    return fit

# %%
fit_value = []
for individual in population:
    a= fitness_starg1(individual)
    fit_value.append(a)
fit_value
# Out:
# [896.0124051125495,
#  948.8383007625104,
#  758.0811925578649,
#  904.2247650383163,
#  671.6505007558578,
#  764.6786157168585,
#  919.9469926119517,
#  855.2269298011607,
#  942.6262001647684,
#  931.8756478726328,
#  801.551369225849,
#  797.0815354693528,
#  893.7660416947454,
#  922.7166277285681,
#  874.1969512987881,
#  840.6145668831854,
#  952.9506476080953,
#  929.5725579296674,
#  953.6326468577945,
#  948.4978696257689]

# %%
#Selection
#pilih individu yang bagus
import heapq

parents= heapq.nlargest(4,fit_value)
print(parents)
# Out:
# [953.6326468577945, 952.9506476080953, 948.8383007625104, 948.4978696257689]

# %%
population[fit_value.index(parents[1])]
# Out:
# [8, 40, 64, 87, 102]

# %%
#Croccover
def crossover_4_parents(parent1, parent2, parent3, parent4):
    # Menghitung panjang kromosom
    chromosome_length = len(parent1)

    # Memilih dua titik crossover acak
    crossover_point1 = random.randint(1, chromosome_length - 1)
    crossover_point2 = random.randint(1, chromosome_length - 1)

    # Memastikan titik crossover1 dan crossover2 berbeda
    while crossover_point1 == crossover_point2:
        crossover_point2 = random.randint(1, chromosome_length - 1)

    # Mengurutkan titik crossover
    crossover_point1, crossover_point2 = min(crossover_point1, crossover_point2), max(crossover_point1, crossover_point2)

    # Membuat empat anak baru dengan menggabungkan gen dari empat orangtua
    child1 = parent1[:crossover_point1] + parent2[crossover_point1:crossover_point2] + parent3[crossover_point2:] + parent4[crossover_point2:]
    child2 = parent3[:crossover_point1] + parent4[crossover_point1:crossover_point2] + parent1[crossover_point2:] + parent2[crossover_point2:]
    child3 = parent2[:crossover_point1] + parent1[crossover_point1:crossover_point2] + parent4[crossover_point2:] + parent3[crossover_point2:]
    child4 = parent4[:crossover_point1] + parent3[crossover_point1:crossover_point2] + parent2[crossover_point2:] + parent1[crossover_point2:]

    return child1[:5], child2[:5], child3[:5], child4[:5]

# %%
parents1= population[fit_value.index(parents[0])]
parents2= population[fit_value.index(parents[1])]
parents3= population[fit_value.index(parents[2])]
parents4= population[fit_value.index(parents[3])]

child1, child2, child3, child4 = crossover_4_parents(parents1, parents2, parents3, parents4)
child=[child1, child2, child3, child4]

# %%
#gabungkan init populasi dengan child
population.extend(child)

# %%
#function untuk mutation
def func_mutation(team):
    wr=0
    for h in team:
        wr += df['Win_Rate'][h]

    wr = wr/5
    return wr

# %%
func_mutation(population[2])
# Out:
# 0.41177685635951383

# %%
#hitung wr team
wr_value = []
for individual in population:
    a= func_mutation(individual)
    wr_value.append(a)

wr_value
# Out:
# [0.480693350382269,
#  0.517924836660759,
#  0.41177685635951383,
#  0.506568495819785,
#  0.3591713907785336,
#  0.42177529824426835,
#  0.4967316374794556,
#  0.46708188410767926,
#  0.5092524041949046,
#  0.5050816519634866,
#  0.43776699575415023,
#  0.43437685856640484,
#  0.49626098928081364,
#  0.5017491178513149,
#  0.4829817410490542,
#  0.45242979918363047,
#  0.519036300440139,
#  0.5115974452006975,
#  0.5179970922638754,
#  0.5183048467900376,
#  0.5075477737641718,
#  0.5218372152105264,
#  0.5254396732980369,
#  0.5184384138820759]

# %%
#mutation rate
new_generation = [value for value in wr_value if value > 0.50]
new_generation
# Out:
# [0.517924836660759,
#  0.506568495819785,
#  0.5092524041949046,
#  0.5050816519634866,
#  0.5017491178513149,
#  0.519036300440139,
#  0.5115974452006975,
#  0.5179970922638754,
#  0.5183048467900376,
#  0.5075477737641718,
#  0.5218372152105264,
#  0.5254396732980369,
#  0.5184384138820759]

# %%
new_pop= []
index =[]
for i in new_generation:
    ind = wr_value.index(i)
    index.append(ind)

# %%
for i in index:
    new_pop.append(population[i])

# %%
new_pop
# Out:
# [[1, 33, 58, 92, 114],
#  [4, 19, 72, 90, 102],
#  [16, 37, 64, 87, 58],
#  [10, 36, 71, 85, 44],
#  [2, 30, 73, 86, 109],
#  [8, 40, 64, 87, 102],
#  [16, 27, 51, 83, 113],
#  [9, 31, 53, 97, 52],
#  [15, 25, 57, 85, 64],
#  [9, 31, 64, 92, 114],
#  [1, 33, 57, 97, 52],
#  [8, 40, 53, 85, 64],
#  [15, 25, 58, 87, 102]]

# %%
fit_value = []
for individual in new_pop:
    a= fitness_starg1(individual)
    fit_value.append(a)
fit_value
# Out:
# [948.8383007625104,
#  904.2247650383163,
#  942.6262001647684,
#  931.8756478726328,
#  922.7166277285681,
#  952.9506476080953,
#  929.5725579296674,
#  953.6326468577945,
#  948.4978696257689,
#  903.94258507399,
#  957.571289911316,
#  969.961636908176,
#  973.1089028566564]

# %%
for individual in new_pop:
    hero1=df['Name'][individual[0]]
    hero2=df['Name'][individual[1]]
    hero3=df['Name'][individual[2]]
    hero4=df['Name'][individual[3]]
    hero5=df['Name'][individual[4]]
    tim=[hero1, hero2, hero3, hero4, hero5]
    print(tim)
# Out:
# ['Beatrix', 'Lylia', 'Julian', 'Uranus', 'Yi_Sun-Shin']
# ['Claude', 'Alice', 'Thamuz', 'Khufra', 'Aamon']
# ['Natan', 'Vale', 'Masha', 'Grock', 'Julian']
# ['Kimmy', 'Pharsa', 'Terizla', 'Gatotkaca', 'Aldous']
# ['Brody', 'Kagura', 'X.Borg', 'Gloo', 'Karina']
# ['Irithel', 'Vexana', 'Masha', 'Grock', 'Aamon']
# ['Natan', 'Harith', 'Bane', 'Franco', 'Selena']
# ['Karrie', 'Lunox', 'Dyrroth', 'Faramis', 'Chou']
# ['Moskov', 'Eudora', 'Jawhead', 'Gatotkaca', 'Masha']
# ['Karrie', 'Lunox', 'Masha', 'Uranus', 'Yi_Sun-Shin']
# ['Beatrix', 'Lylia', 'Jawhead', 'Faramis', 'Chou']
# ['Irithel', 'Vexana', 'Dyrroth', 'Gatotkaca', 'Masha']
# ['Moskov', 'Eudora', 'Julian', 'Grock', 'Aamon']
